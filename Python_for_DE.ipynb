# %% [markdown]
# <a href="https://colab.research.google.com/github/Opeyemidaniel/od-repos/blob/main/Python_for_DE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from csv import reader
import pandas as pd
open_file = pd.read_csv("https://docs.google.com/spreadsheets/d/1scph7kBHCOtjz9BHY5jmQWbhDA2NOX7k0pC9_WAZebA/edit?usp=share_link", error_bad_lines=False)
#read_file = reader(open_file)
#dataset = list(open_file)
open_file.head(5)
#print(dataset)
# Out:
# b'Skipping line 4: expected 16 fields, saw 17\nSkipping line 5: expected 16 fields, saw 691\nSkipping line 12: expected 16 fields, saw 28\nSkipping line 19: expected 16 fields, saw 30\nSkipping line 20: expected 16 fields, saw 22\nSkipping line 28: expected 16 fields, saw 17\nSkipping line 33: expected 16 fields, saw 18\nSkipping line 35: expected 16 fields, saw 17\nSkipping line 41: expected 16 fields, saw 17\nSkipping line 43: expected 16 fields, saw 27\nSkipping line 44: expected 16 fields, saw 26\nSkipping line 45: expected 16 fields, saw 25\nSkipping line 47: expected 16 fields, saw 28\nSkipping line 48: expected 16 fields, saw 25\nSkipping line 49: expected 16 fields, saw 28\nSkipping line 51: expected 16 fields, saw 63\nSkipping line 55: expected 16 fields, saw 30\nSkipping line 56: expected 16 fields, saw 65\nSkipping line 57: expected 16 fields, saw 34\nSkipping line 58: expected 16 fields, saw 25\nSkipping line 68: expected 16 fields, saw 31\nSkipping line 72: expected 16 f
# ...

# %%
path = "/content/drive/MyDrive/Dataset/AppleStore.csv"
df1 = pd.read_csv(path)
df1.head(5)
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...
